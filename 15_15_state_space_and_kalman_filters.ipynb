# %% [markdown]
# # 15 State Space And Kalman Filters
#
# State-space models and a Kalman filter demo.
#
# **Короткое объяснение:**
#
# - Данные: синтетический ряд с трендом, сезонностью и шумом (200 точек).
# - Цель: показать ключевые приёмы для изучаемой темы.
#
# **ASCII-визуализация ряда:**
#
# ```
# ▃▃▄▅▄▂▁▁▁▃▆▆▆▄▃▁▂▂▄▆▆▅▄▃▂▂▃▅▆▇▆▄▄▂▃▃▅▅▆▅▄▃▂▃▃▅▆▇▆▅▃▂▃▅▆▇▇▆▅▄
# ```

# %%
# Пример данных (первые 8 строк)
import pandas as pd
import numpy as np
from datetime import datetime
rng = pd.date_range(start="2020-01-01", periods=200, freq="D")
t = np.arange(len(rng))
seasonal = 10 * np.sin(2 * np.pi * t / 30)
trend = 0.05 * t
noise = np.random.normal(scale=2.0, size=len(rng))
series = 50 + trend + seasonal + noise
df = pd.DataFrame({'ds': rng, 'y': series})
df.head(8)

# %%
# Быстрая визуализация (matplotlib)
import matplotlib.pyplot as plt
plt.figure(figsize=(8,3))
plt.plot(df['ds'], df['y'])
plt.title('Synthetic time series')
plt.xlabel('Date')
plt.ylabel('Value')
plt.tight_layout()
plt.show()

# %%
# Простая демонстрация Kalman (statsmodels)
from statsmodels.tsa.statespace.kalman_filter import KalmanFilter
# Простой пример: мы не обучаем фильтр здесь — показать API
print('KalmanFilter class available:', KalmanFilter)
